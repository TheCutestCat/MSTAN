# %%
from Models.MSTAN import trainer_MSTAN_proba
mytrainer = trainer_MSTAN_proba()
mytrainer.load(name='test_loss_best')
# Out:
# model loaded from save\test_loss.pt

# %%
mytrainer.get_show_data(index = 30,confidence=0.5)

# %%
mytrainer.show(1)
