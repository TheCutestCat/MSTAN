# %%
from models.models import trainer
mytrainer = trainer()

# %%
mytrainer.get_show_data(index = 23)

# %%
mytrainer.show(31)

# %%
data_path = '../data/test_small_data.csv'
import pandas as pd
df = pd.read_csv(data_path)
df_p = df['power']

# %%
from matplotlib import pyplot as plt

plt.plot(df_p[100:])
