# %%
from models.models import trainer
mytrainer = trainer()

# %%
mytrainer.load(name = 'test_loss')
# Out:
# model loaded from save\test_loss.pt

# %%
mytrainer.get_show_data(20,confidence = 0.999)

# %%
mytrainer.show(31) #这个好像并不是比较理想，尤其是对于这种比较靠近边界的地方，而且我们的alpha beta是受限的
