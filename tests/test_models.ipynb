# %%
from models.models import trainer
mytrainer = trainer()

# %%
mytrainer.load(name = 'epoch_20_save')
# Out:
# model loaded from ..\save\epoch_20_save.pt

# %%
mytrainer.train(30)
# Out:
# epoch 1  -1.483987808227539
# epoch 2  -1.4966418743133545
# epoch 3  -1.4965450763702393
# epoch 4  -1.5048341751098633
# epoch 5  -1.4994653463363647
# epoch 6  -1.5144762992858887
# epoch 7  -1.5200588703155518
# epoch 8  -1.5234341621398926
# epoch 9  -1.5220329761505127
# epoch 10  -1.526854395866394
# epoch 11  -1.5143184661865234
# epoch 12  -1.528188705444336
# epoch 13  -1.535615086555481
# epoch 14  -1.5471012592315674
# epoch 15  -1.5408859252929688
# epoch 16  -1.5524306297302246
# epoch 17  -1.557869553565979
# epoch 18  -1.5623441934585571
# epoch 19  -1.5658711194992065
# epoch 20  -1.5714178085327148
# epoch 21  -1.5752538442611694
# epoch 22  -1.5793684720993042
# epoch 23  -1.5785496234893799
# epoch 24  -1.4983917474746704
# epoch 25  -1.5776562690734863
# epoch 26  -1.588476300239563
# epoch 27  -1.5932320356369019
# epoch 28  -1.589545488357544
# epoch 29  -1.6027312278747559
# epoch 30  -1.6096587181091309

# %%
mytrainer.get_show_data(5)

# %%
mytrainer.show(10) #这个好像并不是比较理想，尤其是对于这种比较靠近边界的地方，而且我们的alpha beta是受限的
