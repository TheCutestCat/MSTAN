# %%
from models.models import trainer
from config import *

mytrainer = trainer()

# %%
mytrainer.train(epoch = 10)
test = mytrainer.test() # 从48小时的预测结果来找到
# Out:
# epoch 1  -0.10123854130506516
# epoch 2  -0.1891293227672577
# epoch 3  -0.3028516471385956
# epoch 4  -0.49006515741348267
# epoch 5  -0.6784211993217468
# epoch 6  -0.7782243490219116
# epoch 7  -0.8085142970085144
# epoch 8  -0.8412049412727356
# epoch 9  -0.8787179589271545
# epoch 10  -0.9420287609100342
# loss is 0.09656640912516642
# <function models.models.Loss(alpha, beta, pi, y)>

# %%
mytrainer.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mytrainer.show()
#
# File E:\code\MSTAN\models\models.py:255, in trainer.show(self)
#     252 show_y_pre = y_pre[0,:]
#     254 plt.figure(figsize=(13, 6))
# --> 255 plt.plot(show_y, linestyle='--', label='pre')
#     256 plt.plot(show_y_pre, linestyle='-', label='real')
#     257 plt.legend()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\pyplot.py:2748, in plot(scalex, scaley, data, *args, **kwargs)
#    2746 @_copy_docstring_and_deprecators(Axes.plot)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2748     return gca().plot(
#    2749         *args, scalex=scalex, scaley=scaley,
#    2750         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
