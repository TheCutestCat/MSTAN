# %%
from models.models import trainer
mytrainer = trainer()

# %%
mytrainer.load(name = 'best_loss_proba')
# Out:
# model loaded from save\best_loss_proba.pt

# %%
mytrainer.get_show_data(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mytrainer.get_show_data(10)
#
# File E:\code\MSTAN\models\models.py:377, in trainer.get_show_data(self, index)
#     374 en_x, wind_x, other_x, y = en_x.to(self.device), wind_x.to(self.device), other_x.to(self.device), y.to(self.device)
#     375 alpha, beta, pi, y = self.myEnsemble(en_x, wind_x, other_x, y)
# --> 377 lower_bounds,upper_bounds = GetY_pre(alpha, beta, pi,confidence=0.5)
#     378 show_y = y #[0,:]
#     379 show_y_pre_lower = lower_bounds
#
# File E:\code\MSTAN\models\models.py:239, in GetY_pre(alpha, beta, pi, confidence)
#     236 upper_bound_percentile = 1 - lower_bound_percentile
#     238 # 计算置信区间
# --> 239 lower_bounds = SCI_beta.ppf(lower_bound_percentile, alpha, alpha)
#     240 upper_bounds = SCI_beta.ppf(upper_bound_percentile, alpha, alpha)
# ...

# %%
mytrainer.show(5) #这个好像并不是比较理想，尤其是对于这种比较靠近边界的地方，而且我们的alpha beta是受限的

# %%
mytrainer.show(1) #这个好像并不是比较理想，尤其是对于这种比较靠近边界的地方，而且我们的alpha beta是受限的
