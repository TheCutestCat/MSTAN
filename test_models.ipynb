# %%
from models.models import trainer
mytrainer = trainer()

# %%
mytrainer.load(name = 'best_loss_0.061')
# Out:
# model loaded from save\best_loss_0.061.pt

# %%
mytrainer.get_show_data(10)

# %%
mytrainer.show(9) #这个好像并不是比较理想，尤其是对于这种比较靠近边界的地方，而且我们的alpha beta是受限的
